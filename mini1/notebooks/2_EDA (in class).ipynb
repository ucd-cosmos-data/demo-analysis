# %%
import pandas as pd
import numpy as np

# %%
county_data = pd.read_csv("../data/interim/ca_county_aqi_asthma.csv")

# %%
county_data.head()

# %%
county_data.info()

# %% [markdown]
# ## Scatter Plot

# %%
import matplotlib.pyplot as plt

# %%
# Scatter plot

# %%
## Save as svg

# %% [markdown]
# ## Choropleth Map

# %%
import geopandas as gpd
county = gpd.read_file('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json')
ca_county = county[county['STATE'] == '06']
ca_geojson = ca_county.__geo_interface__

# %%
import plotly.express as px

# %%
# Choropleth maps

# %%
# Save as html
