# %% [markdown]
# # California County Data: Air Quality (AQI) and Asthma

# %%
import pandas as pd
import requests

# %% [markdown]
# # 1. Asthma

# %%
url = "https://data.cdc.gov/resource/i46a-9kgh.json"
params = {
    "$select": "stateabbr,countyname,casthma_adjprev",
    "stateabbr": "CA",
    "$limit": 100,
}

r = requests.get(url, params=params)
r.raise_for_status()

asthma_ca = pd.DataFrame(r.json())

# %%
asthma_ca.head()
# Out:
#   stateabbr countyname casthma_adjprev
# 0        CA     Solano            10.1
# 1        CA     Placer            10.0
# 2        CA      Kings             9.7
# 3        CA     Fresno             9.8
# 4        CA     Amador            10.1

# %% [markdown]
# ## 2. AQI data

# %% [markdown]
# How can i get AQI data by county?
#
# SEARCH!

# %% [markdown]
# ## 3. Merge

# %% [markdown]
# ## 4. Save
